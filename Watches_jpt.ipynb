# %%
import pandas as pd
df = pd.read_csv('Watches.csv')

# %%
from sklearn.impute import SimpleImputer

si = SimpleImputer(strategy='most_frequent')

df = pd.DataFrame(si.fit_transform(df), columns=df.columns)

# %%
df.shape
# Out:
# (284491, 14)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# name          0
# price         0
# brand         0
# model         0
# ref           0
# mvmt          0
# casem         0
# bracem        0
# yop           0
# cond          0
# sex           0
# size          0
# condition     0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0    object
# name          object
# price         object
# brand         object
# model         object
# ref           object
# mvmt          object
# casem         object
# bracem        object
# yop           object
# cond          object
# sex           object
# size          object
# condition     object
# dtype: object

# %%
from pycaret.regression import *

# %%
s = setup(df, target='price', verbose=True, categorical_features=list(df.drop(columns='price').columns))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 s = setup(df, target='price', verbose=True, categorical_features=list(df.drop(columns='price').columns))
#
# ...

# %%
s.compare_models()
